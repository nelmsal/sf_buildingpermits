# %% [markdown]
# # Permit Metrics

# %% [markdown]
# ## Set API Token

# %%
import os
os.chdir(r'C:\Users\nelms\Documents\Penn\CPLN-680\Permit_Metrics')

# %%
# %load_ext autoreload
# %autoreload 2

from accela.GetAppInfo import GetAppUserInfo
app_info_path = r'C:\Users\nelms\Documents\Code\keys\permit_metric_app.json'
user_info_path = r'C:\Users\nelms\Documents\Code\keys\accela_user_info.json'
app_info = GetAppUserInfo(app_info_path, user_info_path)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %load_ext autoreload
# %autoreload 2

from accela.GetToken import SetToken, GetToken, get_request
SetToken(agency='CCSF',environment='PROD')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
AccessToken = GetToken()
AccessToken
# Out:
# 'QgA7aUKcgFmRDKog7fUAHtqkfLp11F1YGqtCx_qoL4BLst5mVk1WcGcS2D2c1Rfyq3UxMOuLqPuLSXGqcmPwjnY8LL6hWWT7csXNTU9FxGIqQ_bSmvduYOB7KVviyvZKoL_pPfPy3b-k7XB-mm9kFAbjKDnJYnvm8-IStBkpGt5gfUuCtoOy_YVlNgpbRKg7PyT5tXSLvt_qxoC5UbiMV4HfexmF2kKlSup7Vwn36oXIuZejU-_qfAOTIFgOCfOYcFZtP0YdpHLC105CTfX1Sv_nFCpSkX-jabuLryWTFmO5JTRnl-9V-ugEuBnQ_yrcA2Q39C1ViB64orpHxkczNv96o7sVtbBWUEVzj_Dc2g1zAlqZBiogg0PJsd0x3TODALIWZN2qn64KyUU9jrOWjo3N77vNEi6eJKu0pxBLD0UwNxhGP4GlV6RF5lTPGDZF0'

# %% [markdown]
# ## Basic Pulls

# %%
import urllib

MAIN_URL = 'https://apis.accela.com'
AUTH_URL = 'https://auth.accela.com'
REQUEST_URL = AUTH_URL + '/oauth2/token'

contentType = 'application/x-www-form-urlencoded'

values = {
    #'agency_name':'',
    #'environment':'',
    'grant_type':'password',
    'scope':'records parcels inspections',
    'environment':'PROD',
    'agency':'ccsf'
}
values.update(app_info)
headers = { 'Content-Type' : contentType }

url = REQUEST_URL
data = urllib.parse.urlencode(values).encode("utf-8")
#data = values
req = urllib.request.Request(url, data, headers)
with urllib.request.urlopen(req) as response:
    #htmlSource = response.read()
    the_page = response.read()
    d = json.loads(the_page)

# %%
API_PATH = r'https://apis.accela.com/'
RECORDS_PATH = API_PATH + r'/v4/records'

RECORD = '19CAP-00000-00HJA'
RECORD = '15CAP-00000-00615'

WORKFLOW_URL = RECORDS_PATH + f'/{RECORD}/workflowTasks' 

contentType = 'application/x-www-form-urlencoded'

headers = { 
    'Authorization' : AccessToken,
    'Content-Type' : contentType
    }
parameters = None

records = get_request(WORKFLOW_URL, parameters, headers)
records
# Out:
# {'result': [{'isActive': 'N',
#    'dueDateString': '2015-06-22T00:00:00',
#    'dueDate': '2015-06-22 00:00:00',
#    'skipIndicator': '000',
#    'comment': 'created record and docket, processed payment, assigned workflow, drafted email to staff, uploaded digital files.',
#    'assignedDate': '2015-06-22 00:00:00',
#    'description': 'Application Intake',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-06-22T15:51:09',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-06-22 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-06-22 15:51:09',
#    'id': '1-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'Application Accepted',
#     'text': 'Application Accepted'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-06-22T00:00:00',
#    'dueDate': '2015-06-22 00:00:00',
#    'skipIndicator': '000',
#    'assignedDate': '2015-09-09 00:00:00',
#    'description': 'Environmental Planning',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-09-17T21:05:48',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-09-17 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-09-17 21:05:48',
#    'id': '3-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'PPA Letter Section Complete',
#     'text': 'PPA Letter Section Complete'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-06-22T00:00:00',
#    'dueDate': '2015-06-22 00:00:00',
#    'skipIndicator': '000',
#    'assignedDate': '2015-06-29 00:00:00',
#    'description': 'Citywide Planning',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-09-17T21:06:10',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-09-17 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-09-17 21:06:10',
#    'id': '5-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'PPA Letter Section Complete',
#     'text': 'PPA Letter Section Complete'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-06-22T00:00:00',
#    'dueDate': '2015-06-22 00:00:00',
#    'skipIndicator': '000',
#    'assignedDate': '2015-09-02 00:00:00',
#    'description': 'Current Planning',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-09-17T21:07:00',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-09-17 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-09-17 21:07:00',
#    'id': '6-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'PPA Letter Section Complete',
#     'text': 'PPA Letter Section Complete'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-06-22T00:00:00',
#    'dueDate': '2015-06-22 00:00:00',
#    'skipIndicator': '000',
#    'assignedDate': '2015-06-22 00:00:00',
#    'description': 'Design Review',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-09-17T21:07:23',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-09-17 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-09-17 21:07:23',
#    'id': '7-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'PPA Letter Section Complete',
#     'text': 'PPA Letter Section Complete'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-09-17T00:00:00',
#    'dueDate': '2015-09-17 00:00:00',
#    'skipIndicator': '000',
#    'assignedDate': '2015-09-17 00:00:00',
#    'description': 'Completion Processing',
#    'commentDisplay': 'N',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-09-17T21:07:53',
#    'processCode': 'PLN_PPA',
#    'statusDate': '2015-09-17 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-09-17 21:07:53',
#    'id': '4-13223',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'PPA Letter Issued', 'text': 'PPA Letter Issued'}},
#   {'isActive': 'N',
#    'dueDateString': '2015-10-27T00:00:00',
#    'dueDate': '2015-10-27 00:00:00',
#    'skipIndicator': '000',
#    'comment': 'call to architect re: height issue; survey submittal.',
#    'assignedDate': '2015-10-05 00:00:00',
#    'description': 'Post-Completion Review',
#    'dispositionNote': 'Follow-Up Meeting',
#    'commentDisplay': 'Y',
#    'serviceProviderCode': 'CCSF',
#    'lastModifiedDateString': '2015-12-02T11:40:13',
#    'processCode': 'ADHOC WORKFLOW',
#    'statusDate': '2015-12-02 00:00:00',
#    'isCompleted': 'Y',
#    'lastModifiedDate': '2015-12-02 11:40:13',
#    'id': '8-13138',
#    'recordId': {'id': 'CCSF-15CAP-00000-00615',
#     'serviceProviderCode': 'CCSF',
#     'customId': '2015-007816PPA',
#     'trackingId': 289122112,
#     'capClass': 'COMPLETE',
#     'value': '15CAP-00000-00615'},
#    'status': {'value': 'Closed', 'text': 'Closed'},
#    'commentPublicVisible': ['All']}],
#  'status': 200}

# %%
records['result'][1]
# Out:
# {'assignedDate': '2020-03-30 00:00:00',
#  'description': 'Project',
#  'isCompleted': 'N',
#  'isActive': 'Y',
#  'dueDateString': '2020-03-30T00:00:00',
#  'dueDate': '2020-03-30 00:00:00',
#  'skipIndicator': '000',
#  'processCode': 'PLN_PRJ',
#  'statusDate': '2020-10-08 00:00:00',
#  'commentDisplay': 'N',
#  'serviceProviderCode': 'CCSF',
#  'lastModifiedDateString': '2020-10-08T13:19:26',
#  'lastModifiedDate': '2020-10-08 13:19:26',
#  'comment': 'correspondence',
#  'id': '1-13231',
#  'recordId': {'id': 'CCSF-19CAP-00000-00HJA',
#   'customId': '2019-022617PRJ',
#   'capClass': 'COMPLETE',
#   'trackingId': 278997255,
#   'serviceProviderCode': 'CCSF',
#   'value': '19CAP-00000-00HJA'},
#  'status': {'value': 'Under Review', 'text': 'Under Review'}}

# %%
pd.DataFrame(records['result'])
# Out:
#           assignedDate         description isCompleted isActive  \
# 0  2019-12-06 00:00:00  Application Intake           Y        N
# 1  2020-03-30 00:00:00             Project           N        Y
#
#          dueDateString              dueDate skipIndicator processCode  \
# 0  2019-12-06T00:00:00  2019-12-06 00:00:00           000     PLN_PRJ
# 1  2020-03-30T00:00:00  2020-03-30 00:00:00           000     PLN_PRJ
#
#             statusDate commentDisplay serviceProviderCode  \
# 0  2020-03-02 00:00:00              N                CCSF
# 1  2020-10-08 00:00:00              N                CCSF
#
#   lastModifiedDateString     lastModifiedDate        id  \
# 0    2020-03-30T08:42:03  2020-03-30 08:42:03  12-13231
# 1    2020-10-08T13:19:26  2020-10-08 13:19:26   1-13231
#
#                                             recordId  \
# 0  {'id': 'CCSF-19CAP-00000-00HJA', 'customId': '...
# 1  {'id': 'CCSF-19CAP-00000-00HJA', 'customId': '...
#
#                                               status         comment
# 0  {'value': 'Application Accepted', 'text': 'App...             NaN
# 1  {'value': 'Under Review', 'text': 'Under Review'}  correspondence

# %%
import pandas as pd
pd.DataFrame([field['fields'] for field in records['result'][2]['rows']])
# Out:
#       Dwelling Unit Type ADU Area Proposed Net Existing
# 0                Studios     None       29   2       27
# 1            One Bedroom     None        1   1        0
# 2            Two Bedroom     None        0   0        0
# 3  Three Bedroom (and +)     None        0   0        0
# 4  Group Housing - Rooms     None        0   0        0
# 5   Group Housing - Beds     None        0   0        0
# 6                    SRO     None        0   0        0
# 7                  Micro     None        0   0        0

# %%
import requests
import json

url = 'https://apis.accela.com/v4/agencies'

contentType = 'application/json'
headers = { 
    #'Authorization' : token,
    'x-accela-appid': app_id,
    'Content-Type' : contentType 
    }

def get_AccelaJson(accelaurl):
    response = requests.request('GET', accelaurl, headers=headers)
    d = response.json()
    
    return d

agencies = get_AccelaJson(url)

# %%
import pandas as pd
a_df = pd.DataFrame(agencies['result'])
a_df = a_df[(a_df['isForDemo']==False)&(~a_df['state'].isna())&(a_df['state']!='')]

a_df.to_csv(r'./static_data/agencies.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\nelms\OneDrive - walnut-creek.org\Projects\Server_Updates\Scripts\API_Test_Notebook.ipynb Cell 3' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/nelms/OneDrive%20-%20walnut-creek.org/Projects/Server_Updates/Scripts/API_Test_Notebook.ipynb#ch0000002?line=0'>1</a> get_app_info(app_info_path)
#
# File c:\Users\nelms\OneDrive - walnut-creek.org\Projects\Server_Updates\Scripts\Accela\GetLoginInfo.py:4, in get_app_info(app_info_path)
#       <a href='file:///c%3A/Users/nelms/OneDrive%20-%20walnut-creek.org/Projects/Server_Updates/Scripts/Accela/GetLoginInfo.py?line=2'>3</a> def get_app_info(app_info_path):
# ----> <a href='file:///c%3A/Users/nelms/OneDrive%20-%20walnut-creek.org/Projects/Server_Updates/Scripts/Accela/GetLoginInfo.py?line=3'>4</a>     app_info = json.load(app_info_path)
#       <a href='file:///c%3A/Users/nelms/OneDrive%20-%20walnut-creek.org/Projects/Server_Updates/Scripts/Accela/GetLoginInfo.py?line=4'>5</a>     return app_info
#
# File C:\ProgramData\Miniconda3\envs\permit_metrics\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=273'>274</a> def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=274'>275</a>         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=275'>276</a>     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=276'>277</a>     a JSON document) to a Python object.
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=277'>278</a>
#    (...)
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=290'>291</a>     kwarg; otherwise ``JSONDecoder`` is used.
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=291'>292</a>     """
# --> <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=292'>293</a>     return loads(fp.read(),
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=293'>294</a>         cls=cls, object_hook=object_hook,
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=294'>295</a>         parse_float=parse_float, parse_int=parse_int,
#     <a href='file:///c%3A/ProgramData/Miniconda3/envs/permit_metrics/lib/json/__init__.py?line=295'>296</a>         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# AttributeError: 'str' object has no attribute 'read'
